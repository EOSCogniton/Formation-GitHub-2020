# %% [markdown]
# <a href="https://colab.research.google.com/github/EOSCogniton/Formation-GitHub-2020/blob/master/Screaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import datetime
from scipy import optimize
from math import *
from numpy import *
import matplotlib.pyplot as plt

#in

#modelisation of the route
def way(x,y,z):

#functions & connections
def len_get(screan_n):
    if(screan_n==screan_0):
        while((way(transpose(position[i]+eul*mat[l;0;0]))<0)or(l>2500)):l=l+1
    elif(screan_n==screan_1):
        while((way(transpose(position[i]+eul*mat[0,l*cos(theda),l*sin(theda)])))or(l>20000)):l=l+1

def arg_get():

def forward(x):
    return [cos(x[0])*cos(x[2])-sin(x[0])*sin(x[2])*cos(x[1]), -cos(x[0])*sin(x[2])-sin(x([0])*cos(x[2])*cos(x[1]),sin(x[0])*sin(x[1])]
  
def mes2eul(y,x):
    return optimize.fsolve(forward-[cos(y[0]),cos(y[1]),cos(y[2])],x)

def car.mode(n):
    if(n==0):
        #run along
        v_wheel1=0
        v_wheel2=2
        v_wheel3=-2
    elif(n=1):
        #turn around
        v_wheel1=2
        v_wheel2=2
        v_wheel3=2
    else:
        #stop
        v_wheel1=0
        v_wheel2=0
        v_wheel3=0

#initialisation
f_est=2
d=5
T_mes=0.01

#pre_mesure
mode=0
car.mode(0)
arg_pre=[]
dis_pre=[]
time.sleep(5/f_est)
N=int(f_est/50)+1
T=N/f_est
while((len_get(screan_1)<3*d)and(len_get(screan_0)<20000))
for i in range (11):
  time.sleep(T)
  lo=len_get(screan_0)
  l1=len_get(screan_1)
  arg_pre.apprend(acos(d/l1))
  dis_pre.apprend(l0)
f=f_est+((sum(arg_pre[1:10])/10-arg_pre[0]/T/(2*pi())
v=(sum(dis_pre[6:10])-sum(dis_pre[0:4])/5/6/T

#screaning
T=T_mes
sample=[]
positon=[[0,0,0]]
point=[]
l=2*d
i=0
arg_eul=[0,0,0]
while(len_get(screan_1)<1.5*d)
while(l>1.5*d)
l=len_get(screan_1)
theda=-pi()/2-acos(d/l)+pi()
time.sleep(1/f/2)
while(len_get(screan_1)>2500)):time.sleep(1/f)
while(True):
  l=len_get(screan_1)
  theda=T*f*2*pi()+theda
  if((abs(theda%(2*pi()-pi()/2)<0.2*pi()))and(l>2500)):
    car.mode(0)
    time.sleep(50)
    car.off(2)
    break
  if(l>2500): continue
  arg_mes=arg_get()
  arg_eul=mes2eul(arg_mes,arg_eul)
  d=len_get(screan_0)
  eul=mat([[cos(arg_eul[0])*cos(arg_eul[2])-sin(arg_eul[0])*cos(arg_eul[1])*sin(arg_eul[2]),sin(arg_eul[0])*cos(arg_eul[1])+cos(arg_eul[0])*cos(arg_eul[1])*sin(arg_eul[2]),sin(arg_eul[1])*sin(arg_eul[2])],
           [-cos(arg_eul[0])*sin(arg_eul[2])-sin(arg_eul[0])*cos(arg_eul[1])*cos(arg_eul[2]),-sin(arg_eul[0])*sin(arg_eul[2])+cos(arg_eul[0])*cos(arg_eul[1]),sin(arg_eul[1])*cos(arg_eul[2])],
           [sin(arg_eul[0])*sin(arg_eul[1]),-cos(arg_eul[0])*sin(arg_eul[1]),cos(arg_eul[1])]])
  if(mode==0):
    position.apprend(position[i]+mat([v*T,0,0])*transpose(eul))
    sample.apprend(position[i+1]+mat([0,d*cos(theda),d*sin(theda])*transpose(eul))
  else:
    position.apprend(position[i])
    sample.apprend(position[i+1]+mat([0,d*cos(theda),d*sin(theda)])*transpose(eul)))
  i=i+1
  if(d<1.5*v*T):
    mode=1
    car.mode(1)
  else:
    mode=0
    car.mode(0)

#diagram
fig=plt.figure()
ax=fig.gca(projection='3d')
ax.set_title("Result")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
axe=ax.plot(position[:,0],position[:,1],position[:,2])
surf=ax.plot_surface(sample[:,0],sample[:,1],sample[:,2],cmap=plt.get_cmap('rainbow'))
plt.show()
